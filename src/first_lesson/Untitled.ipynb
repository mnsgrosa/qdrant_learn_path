# %%
from qdrant_client import QdrantClient, models
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
client = QdrantClient(url=os.getenv("QDRANT_URL"), api_key=os.getenv("QDRANT_API_KEY"))

# %%
collection_name = "first_lesson"

client.create_collection(
    collection_name=collection_name,
    vectors_config=models.VectorParams(
        size=4,
        distance=models.Distance.COSINE
    )
)
# Out:
# ---------------------------------------------------------------------------
# UnexpectedResponse                        Traceback (most recent call last)
# Cell In[13], line 3
#       1 collection_name = "first_lesson"
# ----> 3 client.create_collection(
#       4     collection_name=collection_name,
#       5     vectors_config=models.VectorParams(
#       6         size=4,
#       7         distance=models.Distance.COSINE
#       8     )
#       9 )
#
# File ~/codigos/qdrant_learn_path/.venv/lib/python3.12/site-packages/qdrant_client/qdrant_client.py:1694, in QdrantClient.create_collection(self, collection_name, vectors_config, sparse_vectors_config, shard_number, sharding_method, replication_factor, write_consistency_factor, on_disk_payload, hnsw_config, optimizers_config, wal_config, quantization_config, timeout, strict_mode_config, metadata, **kwargs)
#    1644 """Create empty collection with given parameters
#    1645
#    1646 Args:
#    (...)   1690     Operation result
#    1691 """
#    1692 assert len(kwargs) == 0, f"Unknown arguments: {list(kwargs.keys())}"
# -> 1694 return self._client.create_collection(
#    1695     collection_name=collection_name,
#    1696     vectors_config=vectors_config,
#    1697     shard_number=shard_number,
#    1698     sharding_method=sharding_method,
#    1699     replication_factor=replication_factor,
#    1700     write_consistency_factor=write_consistency_factor,
#    1701     on_disk_payload=on_disk_payload,
#    1702     hnsw_config=hnsw_config,
#    1703     optimizers_config=optimizers_config,
#    1704     wal_config=wal_config,
#    1705     quantization_config=quantization_config,
#    1706     timeout=timeout,
#    1707     sparse_vectors_config=sparse_vectors_config,
#    1708     strict_mode_config=strict_mode_config,
#    1709     metadata=metadata,
#    1710     **kwargs,
#    1711 )
#
# File ~/codigos/qdrant_learn_path/.venv/lib/python3.12/site-packages/qdrant_client/qdrant_remote.py:2023, in QdrantRemote.create_collection(self, collection_name, vectors_config, shard_number, replication_factor, write_consistency_factor, on_disk_payload, hnsw_config, optimizers_config, wal_config, quantization_config, timeout, sparse_vectors_config, sharding_method, strict_mode_config, metadata, **kwargs)
#    2005     quantization_config = GrpcToRest.convert_quantization_config(quantization_config)
#    2007 create_collection_request = models.CreateCollection(
#    2008     vectors=vectors_config,
#    2009     shard_number=shard_number,
#    (...)   2020     metadata=metadata,
#    2021 )
# -> 2023 result: bool | None = self.http.collections_api.create_collection(
#    2024     collection_name=collection_name,
#    2025     create_collection=create_collection_request,
#    2026     timeout=timeout,
#    2027 ).result
#    2029 assert result is not None, "Create collection returned None"
#    2030 return result
#
# File ~/codigos/qdrant_learn_path/.venv/lib/python3.12/site-packages/qdrant_client/http/api/collections_api.py:294, in SyncCollectionsApi.create_collection(self, collection_name, timeout, create_collection)
#     285 def create_collection(
#     286     self,
#     287     collection_name: str,
#     288     timeout: int = None,
#     289     create_collection: m.CreateCollection = None,
#     290 ) -> m.InlineResponse200:
#     291     """
#     292     Create new collection with given parameters
#     293     """
# --> 294     return self._build_for_create_collection(
#     295         collection_name=collection_name,
#     296         timeout=timeout,
#     297         create_collection=create_collection,
#     298     )
#
# File ~/codigos/qdrant_learn_path/.venv/lib/python3.12/site-packages/qdrant_client/http/api/collections_api.py:96, in _CollectionsApi._build_for_create_collection(self, collection_name, timeout, create_collection)
#      94 if "Content-Type" not in headers:
#      95     headers["Content-Type"] = "application/json"
# ---> 96 return self.api_client.request(
#      97     type_=m.InlineResponse200,
#      98     method="PUT",
#      99     url="/collections/{collection_name}",
#     100     headers=headers if headers else None,
#     101     path_params=path_params,
#     102     params=query_params,
#     103     content=body,
#     104 )
#
# File ~/codigos/qdrant_learn_path/.venv/lib/python3.12/site-packages/qdrant_client/http/api_client.py:95, in ApiClient.request(self, type_, method, url, path_params, **kwargs)
#      93     kwargs["timeout"] = int(kwargs["params"]["timeout"])
#      94 request = self._client.build_request(method, url, **kwargs)
# ---> 95 return self.send(request, type_)
#
# File ~/codigos/qdrant_learn_path/.venv/lib/python3.12/site-packages/qdrant_client/http/api_client.py:130, in ApiClient.send(self, request, type_)
#     128     except ValidationError as e:
#     129         raise ResponseHandlingException(e)
# --> 130 raise UnexpectedResponse.for_response(response)
#
# UnexpectedResponse: Unexpected Response: 409 (Conflict)
# Raw response content:
# b'{"status":{"error":"Wrong input: Collection `first_lesson` already exists!"},"time":0.024596575}'

# %%
client.get_collections()
# Out:
# CollectionsResponse(collections=[CollectionDescription(name='first_lesson')])

# %%
points = [
    models.PointStruct(
        id=1,
        vector=[0.1, 0.2, 0.3, 0.4],
        payload={"category":"example"}
    ),
    models.PointStruct(
        id=2,
        vector=[0.2, 0.3, 0.4, 0.5],
        payload={"category":"demo"}
    )
]

client.upsert(
    collection_name=collection_name,
    points=points
)
# Out:
# UpdateResult(operation_id=1, status=<UpdateStatus.COMPLETED: 'completed'>)

# %%
collection_info = client.get_collection(collection_name)
collection_info
# Out:
# CollectionInfo(status=<CollectionStatus.GREEN: 'green'>, optimizer_status=<OptimizersStatusOneOf.OK: 'ok'>, warnings=None, indexed_vectors_count=0, points_count=2, segments_count=2, config=CollectionConfig(params=CollectionParams(vectors=VectorParams(size=4, distance=<Distance.COSINE: 'Cosine'>, hnsw_config=None, quantization_config=None, on_disk=None, datatype=None, multivector_config=None), shard_number=1, sharding_method=None, replication_factor=1, write_consistency_factor=1, read_fan_out_factor=None, on_disk_payload=True, sparse_vectors=None), hnsw_config=HnswConfig(m=16, ef_construct=100, full_scan_threshold=10000, max_indexing_threads=0, on_disk=False, payload_m=None, inline_storage=None), optimizer_config=OptimizersConfig(deleted_threshold=0.2, vacuum_min_vector_number=1000, default_segment_number=0, max_segment_size=None, memmap_threshold=None, indexing_threshold=10000, flush_interval_sec=5, max_optimization_threads=None), wal_config=WalConfig(wal_capacity_mb=32, wal_segments_ahead=0, wal_retain_closed=1), quantization_config=None, strict_mode_config=StrictModeConfigOutput(enabled=True, max_query_limit=None, max_timeout=None, unindexed_filtering_retrieve=False, unindexed_filtering_update=False, search_max_hnsw_ef=None, search_allow_exact=None, search_max_oversampling=None, upsert_max_batchsize=None, max_collection_vector_size_bytes=None, read_rate_limit=None, write_rate_limit=None, max_collection_payload_size_bytes=None, max_points_count=None, filter_max_conditions=None, condition_max_size=None, multivector_config=None, sparse_config=None, max_payload_index_count=100), metadata=None), payload_schema={})

# %%
query_vector = [0.08, 0.14, 0.33, 0.28]

search_results = client.query_points(
    collection_name=collection_name,
    query=query_vector,
    limit=1
)

print(search_results)
# Out:
# points=[ScoredPoint(id=1, version=1, score=0.97642946, payload={'category': 'example'}, vector=None, shard_key=None, order_value=None)]

# %%
new_collection = "first_practice"

client.create_collection(
    collection_name=new_collection,
    vectors_config=models.VectorParams(
        size=4,
        distance=models.Distance.COSINE
    )
)
# Out:
# True

# %%
client.create_payload_index(
    collection_name=new_collection,
    field_name="category",
    field_schema=models.PayloadSchemaType.KEYWORD
)
# Out:
# UpdateResult(operation_id=2, status=<UpdateStatus.COMPLETED: 'completed'>)

# %%
points=[
    models.PointStruct(
        id=1,
        vector=[0.9, 0.1, 0.1, 0.8], # High affordability, high innovation
        payload={"name": "Budget Smartphone", "category": "electronics", "price": 299},
    ),
    models.PointStruct(
        id=2,
        vector=[0.2, 0.9, 0.8, 0.5], # High quality, high popularity
        payload={"name": "Bestselling Novel", "category": "books", "price": 19},
    ),
    models.PointStruct(
        id=3,
        vector=[0.8, 0.3, 0.2, 0.9], # High affordability, high innovation (similar to ID 1)
        payload={"name": "Smart Home Hub", "category": "electronics", "price": 89},
    ),
    models.PointStruct(
        id=4,
        vector=[0.95, 0.2, 0.2, 0.9],
       payload={"name": "Dumbphone", "category": "electronics", "price": 100},
    ),models.PointStruct(
    id=2,
    vector=[0.2, 0.9, 0.8, 0.5], # High quality, high popularity
    payload={"name": "Bestselling Novel", "category": "books", "price": 19},
),
   
]

client.upsert(collection_name=collection_name, points=points)
